# %% [markdown]
# <a href="https://colab.research.google.com/github/mfinke17/Python/blob/main/AR_JM_manuscriptfigure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93c50b49-103e-4bc6-a1c2-8390c37523e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93c50b49-103e-4bc6-a1c2-8390c37523e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['']))
display(df2)

# %%
numeric_columns = df2.select_dtypes(include=['float', 'int']).columns
import matplotlib.colors as mcolors
from matplotlib import rcParams
rcParams['figure.dpi'] = 200
# Out:
#                         Unnamed: 0  Age 24-44  Age 45-59  Age 60+  Male  \
# 0                      Stay inside       0.60       0.67     0.69  0.64
# 1             Change leisure plans       0.32       0.30     0.24  0.28
# 2                Change work hours       0.05       0.06     0.04  0.05
# 3                 Worked from home       0.08       0.06     0.05  0.08
# 4          Found place to cool off       0.16       0.08     0.07  0.08
# 5                 Drank more water       0.55       0.62     0.54  0.56
# 6              Dressed differently       0.18       0.18     0.18  0.19
# 7               Changed what I ate       0.15       0.20     0.19  0.16
# 8                    Warned others       0.23       0.27     0.24  0.22
# 9   Talked about ways to stay safe       0.10       0.12     0.15  0.12
# 10                   Helped others       0.09       0.06     0.06  0.08
# 11                             NaN        NaN        NaN      NaN   NaN
#
# ...

# %%
df = df2.iloc[:, :-1]

# Drop row 11 from the DataFrame
df = df.drop(11)

df = df.rename(columns={'Unnamed: 0': ''})

# Set the 'Unnamed: 0' column as the index
df.set_index('', inplace=True)

# Convert the DataFrame to numeric values
df = df.apply(pd.to_numeric, errors='coerce')

colors = ['honeydew', 'lightgreen', 'forestgreen', 'darkgreen']
cmap = mcolors.LinearSegmentedColormap.from_list('Custom', colors)

# Create the heatmap using seaborn
plt.figure(figsize=(10, 6))  # Adjust the figure size as per your preference
sns.heatmap(df, annot=True, cmap=cmap)

# Set the title of the heatmap
plt.title('')

heatmap.set_title('', fontdict={'fontname': 'Arial', 'fontsize': 12})

# Set the y-axis label to an empty string
heatmap.set_ylabel('')

# Set the y-axis tick labels with Arial font and size 12
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontdict={'fontname': 'Arial', 'fontsize': 12})

# Set the x-axis tick labels with Arial font and size 12
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontdict={'fontname': 'Arial', 'fontsize': 12})

plt.xticks(rotation=45)

# Create the colorbar legend
colorbar = heatmap.figure.colorbar(heatmap.collections[0])

# Set the label for the colorbar
colorbar.set_label('Correlation Coefficient', fontname='Arial', fontsize=12)

# Show the heatmap
plt.show()
